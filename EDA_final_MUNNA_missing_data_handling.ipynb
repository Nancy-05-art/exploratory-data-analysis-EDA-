# %% [markdown]
# # Importing important libraries for EDA

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from warnings import filterwarnings
filterwarnings('ignore')

# %% [markdown]
# # Reading dataset

# %%
data = pd.read_csv(r'C:\Users\Asus\Downloads\insurance3.csv')

# %% [markdown]
# # Data Definition
# - age : Age of the policyholder (Numeric)
#
# - sex: Gender of policyholder (Categoric)
#
# - weight: Weight of the policyholder (Numeric)
#
# - bmi: Body mass index, providing an understanding of body, weights that are relatively high or low relative to height, objective index of body weight (kg / m ^ 2) using the ratio of height to weight (Numeric)
#
# - no_of_dependents: Number of dependent persons on the policyholder (Numeric)
#
# - smoker: Indicates policyholder is a smoker or a non-smoker (non-smoker=0;smoker=1) (Categoric)
#
# - claim: The amount claimed by the policyholder (Numeric)
#
# - bloodpressure: Bloodpressure reading of policyholder (Numeric)
#
# - diabetes: Indicates policyholder suffers from diabetes or not (non-diabetic=0; diabetic=1) (Categoric)
#
# - regular_ex: A policyholder regularly excercises or not (no-excercise=0; excercise=1) (Categoric)
#
# - job_title: Job profile of the policyholder (Categoric)
#
# - city: The city in which the policyholder resides (Categoric)
#
# - hereditary_diseases: A policyholder suffering from a hereditary diseases or not (Categoric)

# %% [markdown]
# # top 5 rows of dataframe

# %%
data.head()
# Out:
#     age     sex  weight   bmi hereditary_diseases  no_of_dependents  smoker  \
# 0  60.0    male      64  24.3           NoDisease                 1       0
# 1  49.0  female      75  22.6           NoDisease                 1       0
# 2  32.0  female      64  17.8            Epilepsy                 2       1
# 3  61.0  female      53  36.4           NoDisease                 1       1
# 4  19.0  female      50  20.6           NoDisease                 0       0
#
#           city  bloodpressure  diabetes  regular_ex    job_title    claim
# 0      NewYork             72         0           0        Actor  13112.6
# 1       Boston             78         1           1     Engineer   9567.0
# 2  Phildelphia             88         1           1  Academician  32734.2
# 3    Pittsburg             72         1           0         Chef  48517.6
# 4      Buffalo             82         1           0   HomeMakers   1731.7

# %% [markdown]
# # Bottom 5 rows of dataframe

# %%
data.tail()
# Out:
#         age   sex  weight   bmi hereditary_diseases  no_of_dependents  smoker  \
# 14995  39.0  male      49  28.3           NoDisease                 1       1
# 14996  39.0  male      74  29.6           NoDisease                 4       0
# 14997  20.0  male      62  33.3           NoDisease                 0       0
# 14998  52.0  male      88  36.7           NoDisease                 0       0
# 14999  52.0  male      57  26.4           NoDisease                 3       0
#
#              city  bloodpressure  diabetes  regular_ex        job_title  \
# 14995    Florence             54         1           0        FilmMaker
# 14996       Miami             64         1           0          Student
# 14997       Tampa             52         1           0  FashionDesigner
# 14998  PanamaCity             70         1           0           Farmer
# 14999   Kingsport             72         1           0          Manager
#
#          claim
# 14995  21082.2
# 14996   7512.3
# ...

# %% [markdown]
# # Shape of dataframe

# %%
data.shape
# Out:
# (15000, 13)

# %%
print(f"No of rows: {data.shape[0]}\nNo of columns: {data.shape[1]}")
# Out:
# No of rows: 15000
# No of columns: 13

# %% [markdown]
# # checking duplicate entries

# %%
data.duplicated().sum()
# Out:
# 1096

# %%
data[data.duplicated()]
# Out:
#         age     sex  weight   bmi hereditary_diseases  no_of_dependents  \
# 605    46.0  female      68   NaN           NoDisease                 2
# 608    27.0  female      82   NaN           NoDisease                 3
# 898    48.0  female      67  33.1           Alzheimer                 0
# 919    26.0    male      56  23.7           NoDisease                 2
# 970    48.0  female      70  28.9           NoDisease                 1
# ...     ...     ...     ...   ...                 ...               ...
# 14966  46.0    male      46  22.3           NoDisease                 0
# 14971  18.0  female      53  27.3           NoDisease                 3
# 14987  47.0    male      94  47.5           NoDisease                 1
# 14989  44.0    male      90  38.1           NoDisease                 1
# 14997  20.0    male      62  33.3           NoDisease                 0
#
#        smoker        city  bloodpressure  diabetes  regular_ex  \
# ...

# %%
data.drop_duplicates(inplace=True)

# %%
print(f"No of rows: {data.shape[0]}\nNo of columns: {data.shape[1]}")
# Out:
# No of rows: 13904
# No of columns: 13

# %% [markdown]
# # Checking for Null

# %%
data.isnull().sum()
# Out:
# age                    361
# sex                      0
# weight                   0
# bmi                    901
# hereditary_diseases      0
# no_of_dependents         0
# smoker                   0
# city                     0
# bloodpressure            0
# diabetes                 0
# regular_ex               0
# job_title                0
# claim                    0
# dtype: int64

# %%
round((data.isnull().sum()/data.shape[0])*100,2)
# Out:
# age                    2.60
# sex                    0.00
# weight                 0.00
# bmi                    6.48
# hereditary_diseases    0.00
# no_of_dependents       0.00
# smoker                 0.00
# city                   0.00
# bloodpressure          0.00
# diabetes               0.00
# regular_ex             0.00
# job_title              0.00
# claim                  0.00
# dtype: float64

# %% [markdown]
# # Checking datatype of each feature

# %%
data.dtypes
# Out:
# age                    float64
# sex                     object
# weight                   int64
# bmi                    float64
# hereditary_diseases     object
# no_of_dependents         int64
# smoker                   int64
# city                    object
# bloodpressure            int64
# diabetes                 int64
# regular_ex               int64
# job_title               object
# claim                  float64
# dtype: object

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 13904 entries, 0 to 14999
# Data columns (total 13 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   age                  13543 non-null  float64
#  1   sex                  13904 non-null  object
#  2   weight               13904 non-null  int64
#  3   bmi                  13003 non-null  float64
#  4   hereditary_diseases  13904 non-null  object
#  5   no_of_dependents     13904 non-null  int64
#  6   smoker               13904 non-null  int64
#  7   city                 13904 non-null  object
#  8   bloodpressure        13904 non-null  int64
#  9   diabetes             13904 non-null  int64
#  10  regular_ex           13904 non-null  int64
#  11  job_title            13904 non-null  object
#  12  claim                13904 non-null  float64
# dtypes: float64(3), int64(6), object(4)
# memory usage: 1.5+ MB

# %% [markdown]
# # Display of all columns names

# %%
data.columns
# Out:
# Index(['age', 'sex', 'weight', 'bmi', 'hereditary_diseases',
#        'no_of_dependents', 'smoker', 'city', 'bloodpressure', 'diabetes',
#        'regular_ex', 'job_title', 'claim'],
#       dtype='object')

# %%
data.keys()
# Out:
# Index(['age', 'sex', 'weight', 'bmi', 'hereditary_diseases',
#        'no_of_dependents', 'smoker', 'city', 'bloodpressure', 'diabetes',
#        'regular_ex', 'job_title', 'claim'],
#       dtype='object')

# %% [markdown]
# ## Numerical and categorical columns segregation

# %%
num_col=data.select_dtypes(include='number').columns.to_list()
cat_col=data.select_dtypes(exclude='number').columns.to_list()

# %% [raw]
# cat_col=[]
# num_col=[]
# for col in data.columns:
#     if df[col].dtypes=='O':
#         cat_col.append(col)
#     else:
#         num_col.append(col)

# %%
#sns.axes_style()
#sns.set_style("darkgrid", {"grid.color": ".9", "grid.linestyle": "-"})

# %% [markdown]
# # Statistical description of numerical features`

# %%
data[num_col].describe()
# Out:
#                 age        weight           bmi  no_of_dependents  \
# count  13543.000000  13904.000000  13003.000000      13904.000000
# mean      39.556598     64.894347     30.273483          1.126438
# std       14.011047     13.675070      6.125247          1.225661
# min       18.000000     34.000000     16.000000          0.000000
# 25%       27.000000     54.000000     25.700000          0.000000
# 50%       40.000000     63.000000     29.400000          1.000000
# 75%       52.000000     76.000000     34.400000          2.000000
# max       64.000000     95.000000     53.100000          5.000000
#
#              smoker  bloodpressure      diabetes    regular_ex         claim
# count  13904.000000   13904.000000  13904.000000  13904.000000  13904.000000
# mean       0.200662      68.657652      0.771145      0.230725  13431.813744
# std        0.400510      19.430514      0.420111      0.421312  12142.099413
# ...

# %% [markdown]
# # Statistical description of Categorical features

# %%
data[cat_col].describe().T
# Out:
#                      count unique        top   freq
# sex                  13904      2     female   7091
# hereditary_diseases  13904     10  NoDisease  12965
# city                 13904     91  Nashville    270
# job_title            13904     35    Student   1220

# %% [markdown]
# # Obsevation:

# %% [markdown]
# # Univariate Analysis
# - Categorical Data

# %%
cat_col
# Out:
# ['sex', 'hereditary_diseases', 'city', 'job_title']

# %%
data['hereditary_diseases'].value_counts()
# Out:
# hereditary_diseases
# NoDisease       12965
# Alzheimer         137
# Diabetes          136
# Obesity           130
# EyeDisease        112
# Cancer            107
# Arthritis          88
# HeartDisease       87
# Epilepsy           77
# High BP            65
# Name: count, dtype: int64

# %%
for col in cat_col:
    print(data[col].value_counts(),"\n\n")
# Out:
# sex
# female    7091
# male      6813
# Name: count, dtype: int64
#
#
# hereditary_diseases
# NoDisease       12965
# Alzheimer         137
# Diabetes          136
# Obesity           130
# EyeDisease        112
# Cancer            107
# Arthritis          88
# HeartDisease       87
# Epilepsy           77
# High BP            65
# Name: count, dtype: int64
#
#
# city
# Nashville     270
# Memphis       269
# NewOrleans    268
# Charleston    267
# Brimingham    266
#              ...
# York           68
# Warwick        67
# Syracuse       67
# Baltimore      67
# Trenton        66
# Name: count, Length: 91, dtype: int64
#
#
# job_title
# Student              1220
# HomeMakers            899
# Singer                697
# FilmMaker             675
# Actor                 662
# Dancer                645
# HouseKeeper           622
# Manager               565
# Police                381
# Photographer          370
# Beautician            363
# Engineer              346
# ...

# %% [markdown]
# ### Countplot of all categorical columns

# %%
for col in cat_col:
    plt.figure(figsize=(18,5))
    ax=sns.countplot(x=col,data=data)
    for x in ax.containers:
        ax.bar_label(x)
    ax.tick_params(labelrotation=45)
        
    plt.show()

# %% [markdown]
# ### Pie chart of all categorical columns

# %%
for col in cat_col:
    data[col].value_counts().plot(kind='pie',autopct='%.2f')      
    plt.show()

# %% [markdown]
# # Univariate Analysis
# - Numerical Data

# %%
num_col

# %% [markdown]
# ### histogram and kde plot

# %%
for col in num_col:
    fig,axs=plt.subplots(1,2, figsize=(10,6))
    sns.histplot(data=data,x=col,hue='sex', kde=False, ax=axs[0])
    sns.kdeplot(data[col], ax=axs[1])
    print(f"Skewness of {col}: {data[col].skew()}")
# Out:
# Skewness of age: 0.006109185887158953
# Skewness of weight: 0.28672897616305765
# Skewness of bmi: 0.3774683179762625
# Skewness of no_of_dependents: 0.9315683898573424
# Skewness of smoker: 1.4950015069909044
# Skewness of bloodpressure: -1.969797960048252
# Skewness of diabetes: -1.2910118051797883
# Skewness of regular_ex: 1.2784531440908167
# Skewness of claim: 1.489221351406612

# %% [markdown]
# ### Box plot for outlier detection

# %%
for col in num_col:
    plt.figure(figsize=(8,4))
    sns.boxplot(data,x=col)

# %%
data
# Out:
#         age     sex  weight   bmi hereditary_diseases  no_of_dependents  \
# 0      60.0    male      64  24.3           NoDisease                 1
# 1      49.0  female      75  22.6           NoDisease                 1
# 2      32.0  female      64  17.8            Epilepsy                 2
# 3      61.0  female      53  36.4           NoDisease                 1
# 4      19.0  female      50  20.6           NoDisease                 0
# ...     ...     ...     ...   ...                 ...               ...
# 14994  38.0  female      71  27.3           NoDisease                 1
# 14995  39.0    male      49  28.3           NoDisease                 1
# 14996  39.0    male      74  29.6           NoDisease                 4
# 14998  52.0    male      88  36.7           NoDisease                 0
# 14999  52.0    male      57  26.4           NoDisease                 3
#
#        smoker         city  bloodpressure  diabetes  regular_ex    job_title  \
# ...

# %% [markdown]
# # Bivariate/Multivariate Analysis

# %%
sns.scatterplot(data,x='age',y='bmi',hue='sex',size='no_of_dependents')
plt.show()

# %%
sns.scatterplot(data,x='age',y='bloodpressure',hue='sex')
plt.show()

# %%
sns.boxplot(x='bloodpressure',y='age',data=data)
# Out:
# <Axes: xlabel='bloodpressure', ylabel='age'>

# %%
sns.scatterplot(df,x='smoker',y='bmi')
# Out:
# <Axes: xlabel='smoker', ylabel='bmi'>

# %%
ax=sns.barplot(data, x='smoker',y='age',hue='sex')

for x in ax.containers:
    print(ax.bar_label(x))
# Out:
# [Text(0, 0, '39.9282'), Text(0, 0, '38.8788')]
# [Text(0, 0, '39.5152'), Text(0, 0, '39.0304')]

# %%
sns.heatmap(data[num_col].corr(),annot=True,fmt='0.1f',cmap='Purples')
# Out:
# <Axes: >

# %% [markdown]
# # Missing data handling

# %%
data.shape
# Out:
# (13904, 13)

# %%
data.isnull().sum()
# Out:
# age                    361
# sex                      0
# weight                   0
# bmi                    901
# hereditary_diseases      0
# no_of_dependents         0
# smoker                   0
# city                     0
# bloodpressure            0
# diabetes                 0
# regular_ex               0
# job_title                0
# claim                    0
# dtype: int64

# %%
(data.isnull().sum()/data.shape[0])*100
# Out:
# age                    2.596375
# sex                    0.000000
# weight                 0.000000
# bmi                    6.480150
# hereditary_diseases    0.000000
# no_of_dependents       0.000000
# smoker                 0.000000
# city                   0.000000
# bloodpressure          0.000000
# diabetes               0.000000
# regular_ex             0.000000
# job_title              0.000000
# claim                  0.000000
# dtype: float64

# %%
df = data.copy()

# %% [markdown]
# # method1: dropna()
# - no of null rows have very less percentage of total

# %%
df.shape
# Out:
# (13904, 13)

# %%
#df.dropna(subset=['age'],inplace=True)

# %%
df.dropna(inplace=True,axis=0)

# %%
df.shape
# Out:
# (12642, 13)

# %% [markdown]
# # method2: inputing null values with Mean

# %% [markdown]
# ## fillna()

# %%
df1 = data.copy()

# %%
df1['age'].fillna(value=df1['age'].mean(), inplace=True)

# %%
df1.isnull().sum()
# Out:
# age                      0
# sex                      0
# weight                   0
# bmi                    901
# hereditary_diseases      0
# no_of_dependents         0
# smoker                   0
# city                     0
# bloodpressure            0
# diabetes                 0
# regular_ex               0
# job_title                0
# claim                    0
# dtype: int64

# %%
df1['bmi'].fillna(value=df1['bmi'].mean(), inplace=True)

# %%
df1.isnull().sum()
# Out:
# age                    0
# sex                    0
# weight                 0
# bmi                    0
# hereditary_diseases    0
# no_of_dependents       0
# smoker                 0
# city                   0
# bloodpressure          0
# diabetes               0
# regular_ex             0
# job_title              0
# claim                  0
# dtype: int64

# %%
sns.kdeplot(x='age',data=data,color='red')
sns.kdeplot(x='age',data=df,color='blue')
sns.kdeplot(x='age',data=df1,color='yellow')
plt.show()

# %%
sns.kdeplot(x='bmi',data=data,color='red')
sns.kdeplot(x='bmi',data=df,color='blue')
sns.kdeplot(x='bmi',data=df1,color='yellow')
plt.show()

# %% [markdown]
# # forward and backward fill
# - method='ffill'
# - method='bfill'
# in fillna()

# %%
df2 = data.copy()

# %%
df2['age'].fillna(method='ffill',inplace=True)

# %%
df2.isnull().sum()
# Out:
# age                      0
# sex                      0
# weight                   0
# bmi                    901
# hereditary_diseases      0
# no_of_dependents         0
# smoker                   0
# city                     0
# bloodpressure            0
# diabetes                 0
# regular_ex               0
# job_title                0
# claim                    0
# dtype: int64

# %%
sns.kdeplot(x='age',data=data,color='red')
sns.kdeplot(x='age',data=df,color='blue')
sns.kdeplot(x='age',data=df1,color='yellow')
sns.kdeplot(x='age',data=df2,color='green')
plt.show()

# %%
df2['bmi'].fillna(method='bfill',inplace=True)

# %%
df2.isnull().sum()
# Out:
# age                    0
# sex                    0
# weight                 0
# bmi                    0
# hereditary_diseases    0
# no_of_dependents       0
# smoker                 0
# city                   0
# bloodpressure          0
# diabetes               0
# regular_ex             0
# job_title              0
# claim                  0
# dtype: int64

# %%
def compare_plot(col,df):
    sns.kdeplot(x=col,data=data,color='red')
    sns.kdeplot(x=col,data=df,color='yellow')
    plt.show()
    print(f'WithoutImputationn_Skewness of {col}: {data[col].skew()}')
    print(f'MeanImputation_Skewness of {col}: {df[col].skew()}')

# %%
sns.kdeplot(x='bmi',data=data,color='red')
sns.kdeplot(x='bmi',data=df,color='blue')
sns.kdeplot(x='bmi',data=df1,color='yellow')
sns.kdeplot(x='bmi',data=df2,color='green')
plt.show()

# %% [markdown]
# # SimpleImputer()

# %%
from sklearn.impute import SimpleImputer

# %%
num_col
# Out:
# ['age',
#  'weight',
#  'bmi',
#  'no_of_dependents',
#  'smoker',
#  'bloodpressure',
#  'diabetes',
#  'regular_ex',
#  'claim']

# %%
s_imp = SimpleImputer()

# %%
df_mean=s_imp.fit_transform(data[num_col])

# %%
df_mean
# Out:
# array([[6.00000e+01, 6.40000e+01, 2.43000e+01, ..., 0.00000e+00,
#         0.00000e+00, 1.31126e+04],
#        [4.90000e+01, 7.50000e+01, 2.26000e+01, ..., 1.00000e+00,
#         1.00000e+00, 9.56700e+03],
#        [3.20000e+01, 6.40000e+01, 1.78000e+01, ..., 1.00000e+00,
#         1.00000e+00, 3.27342e+04],
#        ...,
#        [3.90000e+01, 7.40000e+01, 2.96000e+01, ..., 1.00000e+00,
#         0.00000e+00, 7.51230e+03],
#        [5.20000e+01, 8.80000e+01, 3.67000e+01, ..., 1.00000e+00,
#         0.00000e+00, 9.14460e+03],
#        [5.20000e+01, 5.70000e+01, 2.64000e+01, ..., 1.00000e+00,
#         0.00000e+00, 2.59928e+04]])

# %%
data.isnull().sum()
# Out:
# age                    361
# sex                      0
# weight                   0
# bmi                    901
# hereditary_diseases      0
# no_of_dependents         0
# smoker                   0
# city                     0
# bloodpressure            0
# diabetes                 0
# regular_ex               0
# job_title                0
# claim                    0
# dtype: int64

# %%
s_imp.feature_names_in_
# Out:
# array(['age', 'weight', 'bmi', 'no_of_dependents', 'smoker',
#        'bloodpressure', 'diabetes', 'regular_ex', 'claim'], dtype=object)

# %%
df_mean = pd.DataFrame(df_mean,columns=num_col)

# %%
df_mean
# Out:
#         age  weight   bmi  no_of_dependents  smoker  bloodpressure  diabetes  \
# 0      60.0    64.0  24.3               1.0     0.0           72.0       0.0
# 1      49.0    75.0  22.6               1.0     0.0           78.0       1.0
# 2      32.0    64.0  17.8               2.0     1.0           88.0       1.0
# 3      61.0    53.0  36.4               1.0     1.0           72.0       1.0
# 4      19.0    50.0  20.6               0.0     0.0           82.0       1.0
# ...     ...     ...   ...               ...     ...            ...       ...
# 13899  38.0    71.0  27.3               1.0     0.0            0.0       1.0
# 13900  39.0    49.0  28.3               1.0     1.0           54.0       1.0
# 13901  39.0    74.0  29.6               4.0     0.0           64.0       1.0
# 13902  52.0    88.0  36.7               0.0     0.0           70.0       1.0
# 13903  52.0    57.0  26.4               3.0     0.0           72.0       1.0
#
#        regular_ex    claim
# ...

# %%
df_mean.isnull().sum()
# Out:
# age                 0
# weight              0
# bmi                 0
# no_of_dependents    0
# smoker              0
# bloodpressure       0
# diabetes            0
# regular_ex          0
# claim               0
# dtype: int64

# %%
compare_plot('age',df_mean)
# Out:
# WithoutImputationn_Skewness of age: 0.006109185887158953
# MeanImputation_Skewness of age: 0.006190055330509191

# %%
imp = SimpleImputer(strategy='median')

# %%
df_median=imp.fit_transform(data[num_col])

# %%
df_median = pd.DataFrame(df_median,columns=imp.feature_names_in_)

# %%
df_median
# Out:
#         age  weight   bmi  no_of_dependents  smoker  bloodpressure  diabetes  \
# 0      60.0    64.0  24.3               1.0     0.0           72.0       0.0
# 1      49.0    75.0  22.6               1.0     0.0           78.0       1.0
# 2      32.0    64.0  17.8               2.0     1.0           88.0       1.0
# 3      61.0    53.0  36.4               1.0     1.0           72.0       1.0
# 4      19.0    50.0  20.6               0.0     0.0           82.0       1.0
# ...     ...     ...   ...               ...     ...            ...       ...
# 13899  38.0    71.0  27.3               1.0     0.0            0.0       1.0
# 13900  39.0    49.0  28.3               1.0     1.0           54.0       1.0
# 13901  39.0    74.0  29.6               4.0     0.0           64.0       1.0
# 13902  52.0    88.0  36.7               0.0     0.0           70.0       1.0
# 13903  52.0    57.0  26.4               3.0     0.0           72.0       1.0
#
#        regular_ex    claim
# ...

# %%
df_median.isnull().sum()
# Out:
# age                 0
# weight              0
# bmi                 0
# no_of_dependents    0
# smoker              0
# bloodpressure       0
# diabetes            0
# regular_ex          0
# claim               0
# dtype: int64

# %%
compare_plot('bmi',df_median)

# %%
compare_plot('age',df_median)
# Out:
# WithoutImputationn_Skewness of age: 0.006109185887158953
# MeanImputation_Skewness of age: 0.003692706899900579

# %% [markdown]
# # Categorical Data
# - Most Frequent Value imputation (mode)
# - Missing Category

# %%
data
# Out:
#         age     sex  weight   bmi hereditary_diseases  no_of_dependents  \
# 0      60.0    male      64  24.3           NoDisease                 1
# 1      49.0  female      75  22.6           NoDisease                 1
# 2      32.0  female      64  17.8            Epilepsy                 2
# 3      61.0  female      53  36.4           NoDisease                 1
# 4      19.0  female      50  20.6           NoDisease                 0
# ...     ...     ...     ...   ...                 ...               ...
# 14994  38.0  female      71  27.3           NoDisease                 1
# 14995  39.0    male      49  28.3           NoDisease                 1
# 14996  39.0    male      74  29.6           NoDisease                 4
# 14998  52.0    male      88  36.7           NoDisease                 0
# 14999  52.0    male      57  26.4           NoDisease                 3
#
#        smoker         city  bloodpressure  diabetes  regular_ex    job_title  \
# ...

# %%
df4 = data.copy()

# %%
import random

# %%
data['sex']
# Out:
# 0          male
# 1        female
# 2        female
# 3        female
# 4        female
#           ...
# 14994    female
# 14995      male
# 14996      male
# 14998      male
# 14999      male
# Name: sex, Length: 13904, dtype: object

# %%
i = 1
for x in data['sex']:
    if i <6:
        data.loc[i,'sex'] = np.nan
        print()
    else:
        break
    i += 1

# %%
data.head()
# Out:
#     age   sex  weight   bmi hereditary_diseases  no_of_dependents  smoker  \
# 0  60.0  male      64  24.3           NoDisease                 1       0
# 1  49.0   NaN      75  22.6           NoDisease                 1       0
# 2  32.0   NaN      64  17.8            Epilepsy                 2       1
# 3  61.0   NaN      53  36.4           NoDisease                 1       1
# 4  19.0   NaN      50  20.6           NoDisease                 0       0
#
#           city  bloodpressure  diabetes  regular_ex    job_title    claim
# 0      NewYork             72         0           0        Actor  13112.6
# 1       Boston             78         1           1     Engineer   9567.0
# 2  Phildelphia             88         1           1  Academician  32734.2
# 3    Pittsburg             72         1           0         Chef  48517.6
# 4      Buffalo             82         1           0   HomeMakers   1731.7

# %%
data.isnull().sum()
# Out:
# age                    361
# sex                      5
# weight                   0
# bmi                    901
# hereditary_diseases      0
# no_of_dependents         0
# smoker                   0
# city                     0
# bloodpressure            0
# diabetes                 0
# regular_ex               0
# job_title                0
# claim                    0
# dtype: int64

# %%
m_imp = SimpleImputer(strategy='most_frequent')

# %%
df_mode=m_imp.fit_transform(data[cat_col] )

# %%
df_mode = pd.DataFrame(df_mode,columns=cat_col)

# %%
df_mode
# Out:
#           sex hereditary_diseases         city    job_title
# 0        male           NoDisease      NewYork        Actor
# 1      female           NoDisease       Boston     Engineer
# 2      female            Epilepsy  Phildelphia  Academician
# 3      female           NoDisease    Pittsburg         Chef
# 4      female           NoDisease      Buffalo   HomeMakers
# ...       ...                 ...          ...          ...
# 13899  female           NoDisease    Knoxville         Chef
# 13900    male           NoDisease     Florence    FilmMaker
# 13901    male           NoDisease        Miami      Student
# 13902    male           NoDisease   PanamaCity       Farmer
# 13903    male           NoDisease    Kingsport      Manager
#
# [13904 rows x 4 columns]

# %% [markdown]
# # Multivariate imputation of missing value

# %% [markdown]
# ## Iterative Imputer

# %%
from sklearn.experimental import enable_iterative_imputer
from sklearn.impute import IterativeImputer

# %%
data.isnull().sum()
# Out:
# age                    361
# sex                      0
# weight                   0
# bmi                    901
# hereditary_diseases      0
# no_of_dependents         0
# smoker                   0
# city                     0
# bloodpressure            0
# diabetes                 0
# regular_ex               0
# job_title                0
# claim                    0
# dtype: int64

# %%
print(num_col)
# Out:
# ['age', 'weight', 'bmi', 'no_of_dependents', 'smoker', 'bloodpressure', 'diabetes', 'regular_ex', 'claim']

# %%
i_imp = IterativeImputer()

# %%
df_it=i_imp.fit_transform(data[num_col])

# %%
df_it = pd.DataFrame(df_it,columns=i_imp.feature_names_in_)

# %%
df_it
# Out:
#         age  weight   bmi  no_of_dependents  smoker  bloodpressure  diabetes  \
# 0      60.0    64.0  24.3               1.0     0.0           72.0       0.0
# 1      49.0    75.0  22.6               1.0     0.0           78.0       1.0
# 2      32.0    64.0  17.8               2.0     1.0           88.0       1.0
# 3      61.0    53.0  36.4               1.0     1.0           72.0       1.0
# 4      19.0    50.0  20.6               0.0     0.0           82.0       1.0
# ...     ...     ...   ...               ...     ...            ...       ...
# 13899  38.0    71.0  27.3               1.0     0.0            0.0       1.0
# 13900  39.0    49.0  28.3               1.0     1.0           54.0       1.0
# 13901  39.0    74.0  29.6               4.0     0.0           64.0       1.0
# 13902  52.0    88.0  36.7               0.0     0.0           70.0       1.0
# 13903  52.0    57.0  26.4               3.0     0.0           72.0       1.0
#
#        regular_ex    claim
# ...

# %%
df_it.isnull().sum()
# Out:
# age                 0
# weight              0
# bmi                 0
# no_of_dependents    0
# smoker              0
# bloodpressure       0
# diabetes            0
# regular_ex          0
# claim               0
# dtype: int64

# %%
compare_plot('age',df_it)
# Out:
# WithoutImputationn_Skewness of age: 0.006109185887158953
# MeanImputation_Skewness of age: 0.013432469414881078

# %%
compare_plot('bmi',df_it)
# Out:
# WithoutImputationn_Skewness of bmi: 0.3774683179762625
# MeanImputation_Skewness of bmi: 0.37773009211763137

# %% [markdown]
# # KNN Imputer

# %%
from sklearn.impute import KNNImputer

# %%
knn_imp = KNNImputer()

# %%
knn_df = knn_imp.fit_transform(data[num_col])

# %%
knn_df
# Out:
# array([[6.00000e+01, 6.40000e+01, 2.43000e+01, ..., 0.00000e+00,
#         0.00000e+00, 1.31126e+04],
#        [4.90000e+01, 7.50000e+01, 2.26000e+01, ..., 1.00000e+00,
#         1.00000e+00, 9.56700e+03],
#        [3.20000e+01, 6.40000e+01, 1.78000e+01, ..., 1.00000e+00,
#         1.00000e+00, 3.27342e+04],
#        ...,
#        [2.00000e+01, 6.20000e+01, 3.33000e+01, ..., 1.00000e+00,
#         0.00000e+00, 1.39150e+03],
#        [5.20000e+01, 8.80000e+01, 3.67000e+01, ..., 1.00000e+00,
#         0.00000e+00, 9.14460e+03],
#        [5.20000e+01, 5.70000e+01, 2.64000e+01, ..., 1.00000e+00,
#         0.00000e+00, 2.59928e+04]])

# %%
knn_df = pd.DataFrame(knn_df,columns=num_col)

# %%
knn_df.head()
# Out:
#     age  weight   bmi  no_of_dependents  smoker  bloodpressure  diabetes  \
# 0  60.0    64.0  24.3               1.0     0.0           72.0       0.0
# 1  49.0    75.0  22.6               1.0     0.0           78.0       1.0
# 2  32.0    64.0  17.8               2.0     1.0           88.0       1.0
# 3  61.0    53.0  36.4               1.0     1.0           72.0       1.0
# 4  19.0    50.0  20.6               0.0     0.0           82.0       1.0
#
#    regular_ex    claim
# 0         0.0  13112.6
# 1         1.0   9567.0
# 2         1.0  32734.2
# 3         0.0  48517.6
# 4         0.0   1731.7

# %%
knn_df.isnull().sum()
# Out:
# age                 0
# weight              0
# bmi                 0
# no_of_dependents    0
# smoker              0
# bloodpressure       0
# diabetes            0
# regular_ex          0
# claim               0
# dtype: int64

# %%
compare_plot('age',knn_df)
# Out:
# WithoutImputationn_Skewness of age: 0.006109185887158953
# MeanImputation_Skewness of age: 0.023031648524118736

# %%
compare_plot('bmi',knn_df)
# Out:
# WithoutImputationn_Skewness of bmi: 0.3774683179762625
# MeanImputation_Skewness of bmi: 0.3695006279570856

# %%
df = data.copy()

# %%
df
# Out:
#         age     sex  weight   bmi hereditary_diseases  no_of_dependents  \
# 0      60.0    male      64  24.3           NoDisease                 1
# 1      49.0  female      75  22.6           NoDisease                 1
# 2      32.0  female      64  17.8            Epilepsy                 2
# 3      61.0  female      53  36.4           NoDisease                 1
# 4      19.0  female      50  20.6           NoDisease                 0
# ...     ...     ...     ...   ...                 ...               ...
# 14994  38.0  female      71  27.3           NoDisease                 1
# 14995  39.0    male      49  28.3           NoDisease                 1
# 14996  39.0    male      74  29.6           NoDisease                 4
# 14998  52.0    male      88  36.7           NoDisease                 0
# 14999  52.0    male      57  26.4           NoDisease                 3
#
#        smoker         city  bloodpressure  diabetes  regular_ex    job_title  \
# ...

# %%
df.isnull().sum()
# Out:
# age                    396
# sex                      0
# weight                   0
# bmi                    956
# hereditary_diseases      0
# no_of_dependents         0
# smoker                   0
# city                     0
# bloodpressure            0
# diabetes                 0
# regular_ex               0
# job_title                0
# claim                    0
# dtype: int64

# %%
df.shape
# Out:
# (13904, 13)

# %%
df['age'] = knn_df['age']
df['bmi'] = knn_df['bmi']

# %%
df.head()
# Out:
#     age     sex  weight   bmi hereditary_diseases  no_of_dependents  smoker  \
# 0  60.0    male      64  24.3           NoDisease                 1       0
# 1  49.0  female      75  22.6           NoDisease                 1       0
# 2  32.0  female      64  17.8            Epilepsy                 2       1
# 3  61.0  female      53  36.4           NoDisease                 1       1
# 4  19.0  female      50  20.6           NoDisease                 0       0
#
#           city  bloodpressure  diabetes  regular_ex    job_title    claim
# 0      NewYork             72         0           0        Actor  13112.6
# 1       Boston             78         1           1     Engineer   9567.0
# 2  Phildelphia             88         1           1  Academician  32734.2
# 3    Pittsburg             72         1           0         Chef  48517.6
# 4      Buffalo             82         1           0   HomeMakers   1731.7

# %%
df.isnull().sum()
# Out:
# age                    0
# sex                    0
# weight                 0
# bmi                    0
# hereditary_diseases    0
# no_of_dependents       0
# smoker                 0
# city                   0
# bloodpressure          0
# diabetes               0
# regular_ex             0
# job_title              0
# claim                  0
# dtype: int64

# %%
for col in num_col:
    plt.figure(figsize=(5,6))
    sns.boxplot(data=df, x =col)

# %%
d=sns.load_dataset('titanic')

# %%
d.isnull().sum()
# Out:
# survived         0
# pclass           0
# sex              0
# age            177
# sibsp            0
# parch            0
# fare             0
# embarked         2
# class            0
# who              0
# adult_male       0
# deck           688
# embark_town      2
# alive            0
# alone            0
# dtype: int64

# %%
d.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   survived     891 non-null    int64
#  1   pclass       891 non-null    int64
#  2   sex          891 non-null    object
#  3   age          714 non-null    float64
#  4   sibsp        891 non-null    int64
#  5   parch        891 non-null    int64
#  6   fare         891 non-null    float64
#  7   embarked     889 non-null    object
#  8   class        891 non-null    category
#  9   who          891 non-null    object
#  10  adult_male   891 non-null    bool
#  11  deck         203 non-null    category
#  12  embark_town  889 non-null    object
#  13  alive        891 non-null    object
#  14  alone        891 non-null    bool
# dtypes: bool(2), category(2), float64(2), int64(4), object(5)
# memory usage: 80.7+ KB
